# %%
import pandas as pd
import numpy as np 
import seaborn as srn

# %%
dados = pd.read_csv(r'C:\Users\leand\OneDrive\Área de Trabalho\CursoCódigos\13.Prática em Python\dados\dados.csv' , sep = ';')
dados.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
dados['CODIGO'].describe()
# Out:
# count    187.000000
# mean     247.155080
# std      138.750385
# min        1.000000
# 25%      141.000000
# 50%      242.000000
# 75%      372.500000
# max      496.000000
# Name: CODIGO, dtype: float64

# %%
srn.boxplot(dados['CODIGO']).set_title('CODIGO')
# Out:
# Text(0.5, 1.0, 'CODIGO')

# %%
srn.histplot(dados['CODIGO'], color = 'Blue')
# Out:
# <AxesSubplot: xlabel='CODIGO', ylabel='Count'>

# %%
agrupado =  dados.groupby(dados['MUNICIPIO']).size()
agrupado
# Out:
# MUNICIPIO
# AGUDO                         1
# AJURICABA                     1
# ALECRIM                       1
# ALMIRANTE TAMANDARE DO SUL    1
# ALTO FELIZ                    1
#                              ..
# VERA CRUZ                     1
# VIADUTOS                      1
# VICTOR GRAEFF                 1
# VILA MARIA                    1
# VILA NOVA DO SUL              1
# Length: 177, dtype: int64

# %%
agrupado.isduplicated().sum()

# %%
dados.isna().sum()
# Out:
# CODIGO          0
# MUNICIPIO       0
# PIB             0
# VALOREMPENHO    0
# dtype: int64

# %%
dados['PIB'].describe()
# Out:
# count       187.000000
# mean      19808.741337
# std       16984.223244
# min        8236.630000
# 25%       13621.455000
# 50%       17206.190000
# 75%       21429.165000
# max      223848.220000
# Name: PIB, dtype: float64

# %%
srn.distplot(dados['PIB'] , bins = 10 , axlabel = 'PIB').set_title('PIB')
# Out:
# C:\Users\leand\AppData\Local\Temp\ipykernel_7820\1987809747.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dados['PIB'] , bins = 10 , axlabel = 'PIB').set_title('PIB')
# Text(0.5, 1.0, 'PIB')

# %%
dados['VALOREMPENHO'].describe()
# Out:
# count    1.870000e+02
# mean     1.299844e+05
# std      1.615491e+05
# min      1.721300e+02
# 25%      5.251718e+04
# 50%      8.422816e+04
# 75%      1.538961e+05
# max      1.442760e+06
# Name: VALOREMPENHO, dtype: float64

# %%
srn.displot(dados['VALOREMPENHO'])

# %%
agrupado = dados.sort_values('PIB').head(10)
agrupado = agrupado.iloc[:,1:3]
agrupado
agrupado.plot.bar(x='MUNICIPIO',y='PIB', color = 'gray')
# Out:
# <AxesSubplot: xlabel='MUNICIPIO'>

# %%
agrupado = dados.sort_values('VALOREMPENHO').head(10)
agrupado = agrupado.iloc[:,[1,3]]
agrupado
agrupado.plot.bar(x='MUNICIPIO',y='VALOREMPENHO', color = 'gray')
# Out:
# <AxesSubplot: xlabel='MUNICIPIO'>
